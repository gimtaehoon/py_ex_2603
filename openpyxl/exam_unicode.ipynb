# %%
try:
    wrong= encoded.decode('cp949')
    print(wrong)
except UnicodeDecodeError:
    print('인코딩 방식이 맞지 않아 오류 발생')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 try:
# ----> 2     wrong= encoded.decode('cp949')
#       3     print(wrong)
#       4 except UnicodeDecodeError:
#
# NameError: name 'encoded' is not defined
